# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

import requests

# %%
from bs4 import BeautifulSoup

# %%
#year = range(1930, 2022, 4)
#for i in year:
#    print(i)

# %%
year = ['1930', '1934', '1938','1942','1946','1950', '1954', '1958','1962','1966','1970','1974','1978','1982',
        '1986','1990','1994','1998','2002','2006','2010','2014','2018']

# %%
web = 'https://en.wikipedia.org/wiki/2014_FIFA_World_Cup'

# %%
#send request to the website
response = requests.get(web)

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>2014 FIFA World Cup - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"1434469a-2783-4912-a6ba-26ed20517634","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"2014_FIFA_World_Cup","wgTitle":"2014 FIFA World Cup","wgCurRevisionId":1127893635,"wgRevisionId":1127893635,"wgArticleId":656933,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Portuguese-language sources (pt)","All articles with dead external links","Articles with dead external links from October 20
# ...

# %%
content = response.text

# %%
#!pip install lxml

# %%
#use lxml to pass the content before we can extract the data
soup = BeautifulSoup(content, 'lxml')

# %% [markdown]
# To search for anything in our content, we use .find() or findall()
# - soup.find_all('tag', class_='name')

# %%
rank_table = soup.find('table', attrs= {'class': 'wikitable', 'style':"text-align: center; font-size:95"})

# %%
first = rank_table.find('tr', attrs= {'style':"background-color:gold;"})

# %%
#th = rank_table.find('th')
#print(th)
#team = th.find_next_sibling('th')
#th.find_next_sibling('th').text
#print(team)

# %%
sn = first.find('td')
team_ = sn.find_next_sibling('td')
team = team_.text
group_ = team_.find_next_sibling('td')
group = group_.text
#print(group)
total_game_played_ = group_.find_next_sibling('td')
total_game_played = total_game_played_.text
win_ = total_game_played_.find_next_sibling('td')
win = win_.text
draw_ = win_.find_next_sibling('td')
draw = draw_.text
loss_ = draw_.find_next_sibling('td')
loss = loss_.text
points_ = loss_.find_next_sibling('td')
points = points_.text
total_goals_scored_ = points_.find_next_sibling('td')
total_goals_scored = total_goals_scored_.text
total_goals_conceded_ = total_goals_scored_.find_next_sibling('td')
total_goals_conceded = total_goals_conceded_.text
goal_diff_ = total_goals_conceded_.find_next_sibling('td')
goal_diff = goal_diff_.text

# %%
team
# Out:
# '\xa0Germany\n'

# %%
total_game_played
# Out:
# '7\n'

# %%
total_game_played[:-1]
# Out:
# '7'

# %%
group
# Out:
# 'G\n'

# %%
group[:-1]
# Out:
# 'G'

# %%
#soup.find('title').contents[0][:-len(" - Botten Tomatoes")]

# %% [markdown]
# ### Awards

# %%
golden_ball_2014 = soup.find('a', attrs= {'title': 'Lionel Messi'}).text
golden_ball_2014 = soup.find('a', attrs= {'title': 'Lionel Messi'}).text
golden_boot = soup.find('a', attrs= {'title': 'James Rodríguez'}).text
golden_glove = soup.find('a', attrs= {'title': 'Manuel Neuer'}).text

# %%
golden_ball_2014
# Out:
# 'Lionel Messi'

# %%
#golden_ball = []
#golden_boot = []
#golden_glove = []

# %%
#awards = soup.find_all('table', class_='wikitable')
#for award in awards:
#    golden_ball.append(award.find('a', attrs= {'title': 'Lionel Messi'}).text)
 #   golden_boot.append(award.find('a', attrs= {'title': 'James Rodríguez'}).get_text())
 #   golden_glove.append(award.find('a', attrs= {'title': 'Manuel Neuer'}).get_text())

# %% [markdown]
# ### Prize Money

# %%
prize_money = soup.find('span', attrs= {'class': 'mw-headline', 'id':'Prize_money'})

prize_money
# Out:
# <span class="mw-headline" id="Prize_money">Prize money</span>

# %% [markdown]
# ### Refree That Blew Final

# %%
refree_2014 = soup.find('a', attrs= {'title': 'Nicola Rizzoli'}).text

# %%
refree_2014
# Out:
# 'Nicola Rizzoli'

# %% [markdown]
# ### Best Coach

# %% [markdown]
# ### Best Keeper

# %%
top_2014 = {'Team': team, 'G':group, 'Pld':total_game_played, 'W':win, 'D':draw, 'L':loss, 'Pts':points, 
            'GF':total_goals_scored, 'GA':total_goals_conceded, 'GD':goal_diff, 'Golden Ball': golden_ball_2014, 
            'Golden Boot':golden_boot, 'Golden Glove':golden_glove, 'Prize': 35000000, 'Year': 2014, 'Refree':refree_2014, 'Host': 'Brazil'}

# %%
top_2014
# Out:
# {'Team': '\xa0Germany\n',
#  'G': 'G\n',
#  'Pld': '7\n',
#  'W': '6\n',
#  'D': '1\n',
#  'L': '0\n',
#  'Pts': '19\n',
#  'GF': '18\n',
#  'GA': '4\n',
#  'GD': '+14\n',
#  'Golden Ball': 'Lionel Messi',
#  'Golden Boot': 'James Rodríguez',
#  'Golden Glove': 'Manuel Neuer',
#  'Prize': 35000000,
#  'Year': 2014,
#  'Refree': 'Nicola Rizzoli',
#  'Host': 'Brazil'}

# %%
df_2014 = pd.DataFrame(top_2014, index=[0])

# %%
df_2014
# Out:
#          Team    G  Pld    W    D    L   Pts    GF   GA     GD   Golden Ball  \
# 0   Germany\n  G\n  7\n  6\n  1\n  0\n  19\n  18\n  4\n  +14\n  Lionel Messi
#
#        Golden Boot  Golden Glove     Prize  Year          Refree    Host
# 0  James Rodríguez  Manuel Neuer  35000000  2014  Nicola Rizzoli  Brazil

# %%
first_story_paragraph = soup.find("p", "story")
#first_story_paragraph.find_next_sibling("p")
# <p class="story">...</p>

# %%
th = rank_table.find('th')
print(th)
team = th.find_next_sibling('th')
#th.find_next_sibling('th').text
print(team)
group = team.find_next_sibling('th')
print(group)
total_game_played = group.find_next_sibling('th')
print(total_game_played)
win = total_game_played.find_next_sibling('th')
print(win)
draw = win.find_next_sibling('th')
print(draw)
loss = draw.find_next_sibling('th')
print(loss)
points = loss.find_next_sibling('th')
print(points)
total_goals_scored = points.find_next_sibling('th')
print(total_goals_scored)
total_goals_conceded = total_goals_scored.find_next_sibling('th')
print(total_goals_conceded)
goal_diff = total_goals_conceded.find_next_sibling('th')
print(goal_diff)
# Out:
# <th width="28"><abbr title="Ranking in tournament">Pos.</abbr>
# </th>
# <th width="190">Team
# </th>
# <th width="28"><abbr title="Group">G</abbr>
# </th>
# <th width="28"><abbr title="Total games played">Pld</abbr>
# </th>
# <th width="28"><abbr title="Total games won">W</abbr>
# </th>
# <th width="28"><abbr title="Total games drawn (tied)">D</abbr>
# </th>
# <th width="28"><abbr title="Total games lost">L</abbr>
# </th>
# <th width="28"><abbr title="Total points accumulated (teams receive three points for a win, one point for a draw and no points for a loss)">Pts</abbr>
# </th>
# <th width="28"><abbr title="Total goals scored (goals for)">GF</abbr>
# </th>
# <th width="28"><abbr title="Total goals conceded (goals against)">GA</abbr>
# </th>
# <th width="28"><abbr title="Goal difference (GF−GA)">GD</abbr>
# </th>

# %%
first_link.find_all_next(string=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 first_link.find_all_next(string=True)
#
# NameError: name 'first_link' is not defined

# %%
th.find_all_next(string=True)

# %%
th = rank_table.find('th')
print(th)
th.find_next_siblings('th', string=True)
th.find_all_next()

# %%
th

# %%
th.find_next_siblng('th')

# %%
rank_table.find('th').text
rank_table.find_next_sibling('th').text

# %%
#rank_table.find_all('th').text

# %%
#df = pd.read_html(str(rank_table))
#df

# %%
#to find the specific content we want to extract from the web after inpecting the site
#rank_table = soup.find_all('table', class_='wikitable')

# %%
#for winner in rank_table:
#    print(winner.find('th'))

# %%
#soup.find('')

# %%
#rank_table
